# %%
import h5py
from os.path import join

folder_path = r'E:\research\ejhonglab\2021-11-23\2\SyncData001'
data_path = join(folder_path, 'Episode001.h5')

with h5py.File(
    data_path, "r"
) as f:
    #print(f.keys())
    f.visititems(print)
    a = f['AI/pid'][()]
    b = f['AI/olfDispPin'][()]
# Out:
# AI <HDF5 group "/AI" (4 members)>
# AI/Piezo Monitor <HDF5 dataset "Piezo Monitor": shape (40416000, 1), type "<f8">
# AI/flipperMirror <HDF5 dataset "flipperMirror": shape (40416000, 1), type "<f8">
# AI/olfDispPin <HDF5 dataset "olfDispPin": shape (40416000, 1), type "<f8">
# AI/pid <HDF5 dataset "pid": shape (40416000, 1), type "<f8">
# CI <HDF5 group "/CI" (1 members)>
# CI/Frame Counter <HDF5 dataset "Frame Counter": shape (40416000, 1), type "<u4">
# DI <HDF5 group "/DI" (2 members)>
# DI/Frame Out <HDF5 dataset "Frame Out": shape (40416000, 1), type "<u4">
# DI/scopePin <HDF5 dataset "scopePin": shape (40416000, 1), type "<u4">
# Global <HDF5 group "/Global" (1 members)>
# Global/GCtr <HDF5 dataset "GCtr": shape (40416000, 1), type "<u8">

# %%
# %matplotlib notebook
import numpy as np
import matplotlib.pyplot as plt
import pickle

plt.figure(figsize=(14, 4), dpi=80)
# plt.plot(b)
plt.plot(a)
plt.ylabel('pid reading')
# Out:
# <img src="data:image/png;base64,..." width="1120">
# Text(0, 0.5, 'pid reading')
